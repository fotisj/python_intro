# %% [markdown]
# # Einführung in das Programmieren mit Python

# %% [markdown]
# <h3 style="color:green">Hausaufgabe</h3>
#
# Schreiben Sie eine Programm, das rekursiv die Dateigröße aller Dateien und Unterverzeichnisse eines gegebenen Verzeichnis ermittelt. Hier ein Ausschnitt, wie der Inhalt dieser Datei nach dem Ablauf Ihres Programms aussehen könnte:
# ```
#         74 pydelta/requirements.txt
#        691 pydelta/licence.txt
#      39641 pydelta/delta.py
#       2320 pydelta/readme.txt
#      10589 pydelta/docs/conf.py
#          7 pydelta/docs/.gitignore
#       6766 pydelta/docs/Makefile
#       6703 pydelta/docs/make.bat
#        106 pydelta/docs/delta.rst
#         56 pydelta/docs/modules.rst
#        479 pydelta/docs/index.rst
#      24706 pydelta/docs
#      67432 pydelta
# ```
# Ihr Programm sollte:
#
# * als Modul einbindbar sein und dort eine Funktion anbieten, der man den Pfad des zu untersuchenden Verzeichnisses/der zu untersuchenden Datei und die Ausgabedatei mitgibt,
# * wenn es als Hauptprogramm aufgerufen wird, die Analyse des aktuellen Verzeichnisses (`'.'`) auf den Bildschirm schreiben,
# * und nicht nur unter Windows funktionieren.

# %% [markdown]
# ### Musterlösung

# %% [markdown]
# #### Summierungsfunktion: Einfacher Fall (Datei)

# %%
def total_size(path):
    """
    Berechnet die Gesamtgröße des gegebenen Verzeichnis' oder Datei.
    
    path   = Pfad zum zu untersuchenden Verzeichnis / Datei
    output = offenes Dateiobjekt zum Ausgeben
    """
    if os.path.isdir(path):
        pass # TODO
    else: # kein Verzeichnis: Datei. Der Fall ist einfach.
        size = os.path.getsize(path)
        # oder size = os.stat(path).st_size

    print("{:>10} {}".format(size, path))  # Größe rausschreiben
    return size                     # ... und zurückgeben.

# %% [markdown]
# #### Summierungsfunktion: Rekursionsfall (Verzeichnis)

# %%
def total_size(path):
    """
    Berechnet die Gesamtgröße des gegebenen Verzeichnis' oder Datei.
    
    path   = Pfad zum zu untersuchenden Verzeichnis / Datei    
    Rückgabewert = Gesamtgröße von path (int)
    """
    if os.path.isdir(path):
        # Rekursionsfall: Die Größe eines Verzeichnisses ist die Summe der
        # Größen aller Inhalte des Verzeichnisses, also ...
        size = 0                        # Variable zum Aufsummieren
        for name in os.listdir(path):   # Verzeichnis listen
            subdir = os.path.join(path, name)   # Pfad zusammenbauen
            size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
    else: # kein Verzeichnis: Datei. Der Fall ist einfach.
        size = os.path.getsize(path)
        # oder size = os.stat(path).st_size

    print("{:>10} {}".format(size, path))  # Größe rausschreiben
    return size                     # ... und zurückgeben.

# %%
# Wenn als Hauptprogramm aufgerufen, unsere Main-Funktion starten:
if __name__ == "__main__":
    total_size('.')
# Out:
#          0 ./example/.git/branches
#        452 ./example/.git/hooks/applypatch-msg.sample
#        896 ./example/.git/hooks/commit-msg.sample
#        189 ./example/.git/hooks/post-update.sample
#        398 ./example/.git/hooks/pre-applypatch.sample
#       1642 ./example/.git/hooks/pre-commit.sample
#       1352 ./example/.git/hooks/pre-push.sample
#       4898 ./example/.git/hooks/pre-rebase.sample
#       1239 ./example/.git/hooks/prepare-commit-msg.sample
#       3611 ./example/.git/hooks/update.sample
#      14677 ./example/.git/hooks
#        240 ./example/.git/info/exclude
#        240 ./example/.git/info
#        394 ./example/.git/logs/refs/heads/master
#        394 ./example/.git/logs/refs/heads
#        190 ./example/.git/logs/refs/remotes/origin/HEAD
#        161 ./example/.git/logs/refs/remotes/origin/master
#        351 ./example/.git/logs/refs/remotes/origin
#        351 ./example/.git/logs/refs/remotes
#        745 ./example/.git/logs/refs
#       1239 ./example/.git/logs/HEAD
#       1984 ./example/.git/logs
#        203 ./example/.git/objects/4b/48dc44712e6c87482bf04b465fecd5ab3409f7
#        203 ./example/.git/objects/4b
#      13061 ./example/.git/objects/c5/9897ae9cc1276e830938b14832cceecd31b819
#      13061 ./example/.git/objects/c5
#        222 ./example/.git/objects/db/10c710e062acf0f3bd88e615a8a0bf8740bb73
#        222 ./example/.git/objects/db
#          0 ./example/.git/objects/info
#       8856 ./example/.git/objects/pack/pack-967603cfc3620d73cd6b5fb442597be69f53b9c0.idx
#      80502 ./example/.git/objects/pack/pack-967603cfc3620d73cd6b5fb442597be69f53b9c0.pack
#      89358 ./example/.git/objects/pack
#     102844 ./example/.git/objects
#         41 ./example/.git/refs/heads/master
#         41 ./example/.git/refs/heads
#         32 ./example/.git/refs/remotes/origin/HEAD
#         41 ./example/.git/refs/remotes/origin/master
#         73 ./example/.git/refs/remotes/origin
#         73 ./example/.git/refs/remotes
#          0 ./example/.git/refs/tags
#        114 ./example/.git/refs
#          0 ./example/.git/rr-cache
#        345 ./example/.git/COMMIT_EDITMSG
#         23 ./example/.git/HEAD
#          0 ./example/.git/MERGE_RR
#        256 ./example/.git/config
#         73 ./example/.git/description
#       1047 ./example/.git/index
#        396 ./example/.git/packed-refs
#     121999 ./example/.git
#      36309 ./example/__pycache__/delta.cpython-34.pyc
#      36309 ./example/__pycache__
#          7 ./example/docs/.gitignore
#       6766 ./example/docs/Makefile
#      10589 ./example/docs/conf.py
#        106 ./example/docs/delta.rst
#        479 ./example/docs/index.rst
#       6703 ./example/docs/make.bat
#         56 ./example/docs/modules.rst
#      24706 ./example/docs
#         55 ./example/.gitignore
#     374965 ./example/corpus_words.csv
#      39642 ./example/delta.py
#        691 ./example/licence.txt
#       2152 ./example/pydelta.ini
#       2320 ./example/readme.txt
#         74 ./example/requirements.txt
#     602913 ./example
#          0 ./files/example/.git/branches
#        452 ./files/example/.git/hooks/applypatch-msg.sample
#        896 ./files/example/.git/hooks/commit-msg.sample
#        189 ./files/example/.git/hooks/post-update.sample
#        398 ./files/example/.git/hooks/pre-applypatch.sample
#       1642 ./files/example/.git/hooks/pre-commit.sample
#       1352 ./files/example/.git/hooks/pre-push.sample
#       4898 ./files/example/.git/hooks/pre-rebase.sample
#       1239 ./files/example/.git/hooks/prepare-commit-msg.sample
#       3611 ./files/example/.git/hooks/update.sample
#      14677 ./files/example/.git/hooks
#        240 ./files/example/.git/info/exclude
#        240 ./files/example/.git/info
#        394 ./files/example/.git/logs/refs/heads/master
#        394 ./files/example/.git/logs/refs/heads
#        190 ./files/example/.git/logs/refs/remotes/origin/HEAD
#        161 ./files/example/.git/logs/refs/remotes/origin/master
#        351 ./files/example/.git/logs/refs/remotes/origin
#        351 ./files/example/.git/logs/refs/remotes
#        745 ./files/example/.git/logs/refs
#       1239 ./files/example/.git/logs/HEAD
#       1984 ./files/example/.git/logs
#        203 ./files/example/.git/objects/4b/48dc44712e6c87482bf04b465fecd5ab3409f7
#        203 ./files/example/.git/objects/4b
#      13061 ./files/example/.git/objects/c5/9897ae9cc1276e830938b14832cceecd31b819
#      13061 ./files/example/.git/objects/c5
#        222 ./files/example/.git/objects/db/10c710e062acf0f3bd88e615a8a0bf8740bb73
#        222 ./files/example/.git/objects/db
#          0 ./files/example/.git/objects/info
#       8856 ./files/example/.git/objects/pack/pack-967603cfc3620d73cd6b5fb442597be69f53b9c0.idx
#      80502 ./files/example/.git/objects/pack/pack-967603cfc3620d73cd6b5fb442597be69f53b9c0.pack
#      89358 ./files/example/.git/objects/pack
#     102844 ./files/example/.git/objects
#         41 ./files/example/.git/refs/heads/master
#         41 ./files/example/.git/refs/heads
#         32 ./files/example/.git/refs/remotes/origin/HEAD
#         41 ./files/example/.git/refs/remotes/origin/master
#         73 ./files/example/.git/refs/remotes/origin
#         73 ./files/example/.git/refs/remotes
#          0 ./files/example/.git/refs/tags
#        114 ./files/example/.git/refs
#          0 ./files/example/.git/rr-cache
#        345 ./files/example/.git/COMMIT_EDITMSG
#         23 ./files/example/.git/HEAD
#          0 ./files/example/.git/MERGE_RR
#        256 ./files/example/.git/config
#         73 ./files/example/.git/description
#       1047 ./files/example/.git/index
#        396 ./files/example/.git/packed-refs
#     121999 ./files/example/.git
#      36309 ./files/example/__pycache__/delta.cpython-34.pyc
#      36309 ./files/example/__pycache__
#          7 ./files/example/docs/.gitignore
#       6766 ./files/example/docs/Makefile
#      10589 ./files/example/docs/conf.py
#        106 ./files/example/docs/delta.rst
#        479 ./files/example/docs/index.rst
#       6703 ./files/example/docs/make.bat
#         56 ./files/example/docs/modules.rst
#      24706 ./files/example/docs
#         55 ./files/example/.gitignore
#     374965 ./files/example/corpus_words.csv
#      39642 ./files/example/delta.py
#        691 ./files/example/licence.txt
#       2152 ./files/example/pydelta.ini
#       2320 ./files/example/readme.txt
#         74 ./files/example/requirements.txt
#     602913 ./files/example
#          0 ./files/files/example/.git/branches
#        452 ./files/files/example/.git/hooks/applypatch-msg.sample
#        896 ./files/files/example/.git/hooks/commit-msg.sample
#        189 ./files/files/example/.git/hooks/post-update.sample
#        398 ./files/files/example/.git/hooks/pre-applypatch.sample
#       1642 ./files/files/example/.git/hooks/pre-commit.sample
#       1352 ./files/files/example/.git/hooks/pre-push.sample
#       4898 ./files/files/example/.git/hooks/pre-rebase.sample
#       1239 ./files/files/example/.git/hooks/prepare-commit-msg.sample
#       3611 ./files/files/example/.git/hooks/update.sample
#      14677 ./files/files/example/.git/hooks
#        240 ./files/files/example/.git/info/exclude
#        240 ./files/files/example/.git/info
#        394 ./files/files/example/.git/logs/refs/heads/master
#        394 ./files/files/example/.git/logs/refs/heads
#        190 ./files/files/example/.git/logs/refs/remotes/origin/HEAD
#        161 ./files/files/example/.git/logs/refs/remotes/origin/master
#        351 ./files/files/example/.git/logs/refs/remotes/origin
#        351 ./files/files/example/.git/logs/refs/remotes
#        745 ./files/files/example/.git/logs/refs
#       1239 ./files/files/example/.git/logs/HEAD
#       1984 ./files/files/example/.git/logs
#        203 ./files/files/example/.git/objects/4b/48dc44712e6c87482bf04b465fecd5ab3409f7
#        203 ./files/files/example/.git/objects/4b
#      13061 ./files/files/example/.git/objects/c5/9897ae9cc1276e830938b14832cceecd31b819
#      13061 ./files/files/example/.git/objects/c5
#        222 ./files/files/example/.git/objects/db/10c710e062acf0f3bd88e615a8a0bf8740bb73
#        222 ./files/files/example/.git/objects/db
#          0 ./files/files/example/.git/objects/info
#       8856 ./files/files/example/.git/objects/pack/pack-967603cfc3620d73cd6b5fb442597be69f53b9c0.idx
#      80502 ./files/files/example/.git/objects/pack/pack-967603cfc3620d73cd6b5fb442597be69f53b9c0.pack
#      89358 ./files/files/example/.git/objects/pack
#     102844 ./files/files/example/.git/objects
#         41 ./files/files/example/.git/refs/heads/master
#         41 ./files/files/example/.git/refs/heads
#         32 ./files/files/example/.git/refs/remotes/origin/HEAD
#         41 ./files/files/example/.git/refs/remotes/origin/master
#         73 ./files/files/example/.git/refs/remotes/origin
#         73 ./files/files/example/.git/refs/remotes
#          0 ./files/files/example/.git/refs/tags
#        114 ./files/files/example/.git/refs
#          0 ./files/files/example/.git/rr-cache
#        345 ./files/files/example/.git/COMMIT_EDITMSG
#         23 ./files/files/example/.git/HEAD
#          0 ./files/files/example/.git/MERGE_RR
#        256 ./files/files/example/.git/config
#         73 ./files/files/example/.git/description
#       1047 ./files/files/example/.git/index
#        396 ./files/files/example/.git/packed-refs
#     121999 ./files/files/example/.git
#      36309 ./files/files/example/__pycache__/delta.cpython-34.pyc
#      36309 ./files/files/example/__pycache__
#          7 ./files/files/example/docs/.gitignore
#       6766 ./files/files/example/docs/Makefile
#      10589 ./files/files/example/docs/conf.py
#        106 ./files/files/example/docs/delta.rst
#        479 ./files/files/example/docs/index.rst
#       6703 ./files/files/example/docs/make.bat
#         56 ./files/files/example/docs/modules.rst
#      24706 ./files/files/example/docs
#         55 ./files/files/example/.gitignore
#     374965 ./files/files/example/corpus_words.csv
#      39642 ./files/files/example/delta.py
#        691 ./files/files/example/licence.txt
#       2152 ./files/files/example/pydelta.ini
#       2320 ./files/files/example/readme.txt
#         74 ./files/files/example/requirements.txt
#     602913 ./files/files/example
#          0 ./files/files/files/example/.git/branches
#        452 ./files/files/files/example/.git/hooks/applypatch-msg.sample
#        896 ./files/files/files/example/.git/hooks/commit-msg.sample
#        189 ./files/files/files/example/.git/hooks/post-update.sample
#        398 ./files/files/files/example/.git/hooks/pre-applypatch.sample
#       1642 ./files/files/files/example/.git/hooks/pre-commit.sample
#       1352 ./files/files/files/example/.git/hooks/pre-push.sample
#       4898 ./files/files/files/example/.git/hooks/pre-rebase.sample
#       1239 ./files/files/files/example/.git/hooks/prepare-commit-msg.sample
#       3611 ./files/files/files/example/.git/hooks/update.sample
#      14677 ./files/files/files/example/.git/hooks
#        240 ./files/files/files/example/.git/info/exclude
#        240 ./files/files/files/example/.git/info
#        394 ./files/files/files/example/.git/logs/refs/heads/master
#        394 ./files/files/files/example/.git/logs/refs/heads
#        190 ./files/files/files/example/.git/logs/refs/remotes/origin/HEAD
#        161 ./files/files/files/example/.git/logs/refs/remotes/origin/master
#        351 ./files/files/files/example/.git/logs/refs/remotes/origin
#        351 ./files/files/files/example/.git/logs/refs/remotes
#        745 ./files/files/files/example/.git/logs/refs
#       1239 ./files/files/files/example/.git/logs/HEAD
#       1984 ./files/files/files/example/.git/logs
#        203 ./files/files/files/example/.git/objects/4b/48dc44712e6c87482bf04b465fecd5ab3409f7
#        203 ./files/files/files/example/.git/objects/4b
#      13061 ./files/files/files/example/.git/objects/c5/9897ae9cc1276e830938b14832cceecd31b819
#      13061 ./files/files/files/example/.git/objects/c5
#        222 ./files/files/files/example/.git/objects/db/10c710e062acf0f3bd88e615a8a0bf8740bb73
#        222 ./files/files/files/example/.git/objects/db
#          0 ./files/files/files/example/.git/objects/info
#       8856 ./files/files/files/example/.git/objects/pack/pack-967603cfc3620d73cd6b5fb442597be69f53b9c0.idx
#      80502 ./files/files/files/example/.git/objects/pack/pack-967603cfc3620d73cd6b5fb442597be69f53b9c0.pack
#      89358 ./files/files/files/example/.git/objects/pack
#     102844 ./files/files/files/example/.git/objects
#         41 ./files/files/files/example/.git/refs/heads/master
#         41 ./files/files/files/example/.git/refs/heads
#         32 ./files/files/files/example/.git/refs/remotes/origin/HEAD
#         41 ./files/files/files/example/.git/refs/remotes/origin/master
#         73 ./files/files/files/example/.git/refs/remotes/origin
#         73 ./files/files/files/example/.git/refs/remotes
#          0 ./files/files/files/example/.git/refs/tags
#        114 ./files/files/files/example/.git/refs
#          0 ./files/files/files/example/.git/rr-cache
#        345 ./files/files/files/example/.git/COMMIT_EDITMSG
#         23 ./files/files/files/example/.git/HEAD
#          0 ./files/files/files/example/.git/MERGE_RR
#        256 ./files/files/files/example/.git/config
#         73 ./files/files/files/example/.git/description
#       1047 ./files/files/files/example/.git/index
#        396 ./files/files/files/example/.git/packed-refs
#     121999 ./files/files/files/example/.git
#      36309 ./files/files/files/example/__pycache__/delta.cpython-34.pyc
#      36309 ./files/files/files/example/__pycache__
#          7 ./files/files/files/example/docs/.gitignore
#       6766 ./files/files/files/example/docs/Makefile
#      10589 ./files/files/files/example/docs/conf.py
#        106 ./files/files/files/example/docs/delta.rst
#        479 ./files/files/files/example/docs/index.rst
#       6703 ./files/files/files/example/docs/make.bat
#         56 ./files/files/files/example/docs/modules.rst
#      24706 ./files/files/files/example/docs
#         55 ./files/files/files/example/.gitignore
#     374965 ./files/files/files/example/corpus_words.csv
#      39642 ./files/files/files/example/delta.py
#        691 ./files/files/files/example/licence.txt
#       2152 ./files/files/files/example/pydelta.ini
#       2320 ./files/files/files/example/readme.txt
#         74 ./files/files/files/example/requirements.txt
#     602913 ./files/files/files/example
#          0 ./files/files/files/files/example/.git/branches
#        452 ./files/files/files/files/example/.git/hooks/applypatch-msg.sample
#        896 ./files/files/files/files/example/.git/hooks/commit-msg.sample
#        189 ./files/files/files/files/example/.git/hooks/post-update.sample
#        398 ./files/files/files/files/example/.git/hooks/pre-applypatch.sample
#       1642 ./files/files/files/files/example/.git/hooks/pre-commit.sample
#       1352 ./files/files/files/files/example/.git/hooks/pre-push.sample
#       4898 ./files/files/files/files/example/.git/hooks/pre-rebase.sample
#       1239 ./files/files/files/files/example/.git/hooks/prepare-commit-msg.sample
#       3611 ./files/files/files/files/example/.git/hooks/update.sample
#      14677 ./files/files/files/files/example/.git/hooks
#        240 ./files/files/files/files/example/.git/info/exclude
#        240 ./files/files/files/files/example/.git/info
#        394 ./files/files/files/files/example/.git/logs/refs/heads/master
#        394 ./files/files/files/files/example/.git/logs/refs/heads
#        190 ./files/files/files/files/example/.git/logs/refs/remotes/origin/HEAD
#        161 ./files/files/files/files/example/.git/logs/refs/remotes/origin/master
#        351 ./files/files/files/files/example/.git/logs/refs/remotes/origin
#        351 ./files/files/files/files/example/.git/logs/refs/remotes
#        745 ./files/files/files/files/example/.git/logs/refs
#       1239 ./files/files/files/files/example/.git/logs/HEAD
#       1984 ./files/files/files/files/example/.git/logs
#        203 ./files/files/files/files/example/.git/objects/4b/48dc44712e6c87482bf04b465fecd5ab3409f7
#        203 ./files/files/files/files/example/.git/objects/4b
#      13061 ./files/files/files/files/example/.git/objects/c5/9897ae9cc1276e830938b14832cceecd31b819
#      13061 ./files/files/files/files/example/.git/objects/c5
#        222 ./files/files/files/files/example/.git/objects/db/10c710e062acf0f3bd88e615a8a0bf8740bb73
#        222 ./files/files/files/files/example/.git/objects/db
#          0 ./files/files/files/files/example/.git/objects/info
#       8856 ./files/files/files/files/example/.git/objects/pack/pack-967603cfc3620d73cd6b5fb442597be69f53b9c0.idx
#      80502 ./files/files/files/files/example/.git/objects/pack/pack-967603cfc3620d73cd6b5fb442597be69f53b9c0.pack
#      89358 ./files/files/files/files/example/.git/objects/pack
#     102844 ./files/files/files/files/example/.git/objects
#         41 ./files/files/files/files/example/.git/refs/heads/master
#         41 ./files/files/files/files/example/.git/refs/heads
#         32 ./files/files/files/files/example/.git/refs/remotes/origin/HEAD
#         41 ./files/files/files/files/example/.git/refs/remotes/origin/master
#         73 ./files/files/files/files/example/.git/refs/remotes/origin
#         73 ./files/files/files/files/example/.git/refs/remotes
#          0 ./files/files/files/files/example/.git/refs/tags
#        114 ./files/files/files/files/example/.git/refs
#          0 ./files/files/files/files/example/.git/rr-cache
#        345 ./files/files/files/files/example/.git/COMMIT_EDITMSG
#         23 ./files/files/files/files/example/.git/HEAD
#          0 ./files/files/files/files/example/.git/MERGE_RR
#        256 ./files/files/files/files/example/.git/config
#         73 ./files/files/files/files/example/.git/description
#       1047 ./files/files/files/files/example/.git/index
#        396 ./files/files/files/files/example/.git/packed-refs
#     121999 ./files/files/files/files/example/.git
#      36309 ./files/files/files/files/example/__pycache__/delta.cpython-34.pyc
#      36309 ./files/files/files/files/example/__pycache__
#          7 ./files/files/files/files/example/docs/.gitignore
#       6766 ./files/files/files/files/example/docs/Makefile
#      10589 ./files/files/files/files/example/docs/conf.py
#        106 ./files/files/files/files/example/docs/delta.rst
#        479 ./files/files/files/files/example/docs/index.rst
#       6703 ./files/files/files/files/example/docs/make.bat
#         56 ./files/files/files/files/example/docs/modules.rst
#      24706 ./files/files/files/files/example/docs
#         55 ./files/files/files/files/example/.gitignore
#     374965 ./files/files/files/files/example/corpus_words.csv
#      39642 ./files/files/files/files/example/delta.py
#        691 ./files/files/files/files/example/licence.txt
#       2152 ./files/files/files/files/example/pydelta.ini
#       2320 ./files/files/files/files/example/readme.txt
#         74 ./files/files/files/files/example/requirements.txt
#     602913 ./files/files/files/files/example
#          0 ./files/files/files/files/files/example/.git/branches
#        452 ./files/files/files/files/files/example/.git/hooks/applypatch-msg.sample
#        896 ./files/files/files/files/files/example/.git/hooks/commit-msg.sample
#        189 ./files/files/files/files/files/example/.git/hooks/post-update.sample
#        398 ./files/files/files/files/files/example/.git/hooks/pre-applypatch.sample
#       1642 ./files/files/files/files/files/example/.git/hooks/pre-commit.sample
#       1352 ./files/files/files/files/files/example/.git/hooks/pre-push.sample
#       4898 ./files/files/files/files/files/example/.git/hooks/pre-rebase.sample
#       1239 ./files/files/files/files/files/example/.git/hooks/prepare-commit-msg.sample
#       3611 ./files/files/files/files/files/example/.git/hooks/update.sample
#      14677 ./files/files/files/files/files/example/.git/hooks
#        240 ./files/files/files/files/files/example/.git/info/exclude
#        240 ./files/files/files/files/files/example/.git/info
#        394 ./files/files/files/files/files/example/.git/logs/refs/heads/master
#        394 ./files/files/files/files/files/example/.git/logs/refs/heads
#        190 ./files/files/files/files/files/example/.git/logs/refs/remotes/origin/HEAD
#        161 ./files/files/files/files/files/example/.git/logs/refs/remotes/origin/master
#        351 ./files/files/files/files/files/example/.git/logs/refs/remotes/origin
#        351 ./files/files/files/files/files/example/.git/logs/refs/remotes
#        745 ./files/files/files/files/files/example/.git/logs/refs
#       1239 ./files/files/files/files/files/example/.git/logs/HEAD
#       1984 ./files/files/files/files/files/example/.git/logs
#        203 ./files/files/files/files/files/example/.git/objects/4b/48dc44712e6c87482bf04b465fecd5ab3409f7
#        203 ./files/files/files/files/files/example/.git/objects/4b
#      13061 ./files/files/files/files/files/example/.git/objects/c5/9897ae9cc1276e830938b14832cceecd31b819
#      13061 ./files/files/files/files/files/example/.git/objects/c5
#        222 ./files/files/files/files/files/example/.git/objects/db/10c710e062acf0f3bd88e615a8a0bf8740bb73
#        222 ./files/files/files/files/files/example/.git/objects/db
#          0 ./files/files/files/files/files/example/.git/objects/info
#       8856 ./files/files/files/files/files/example/.git/objects/pack/pack-967603cfc3620d73cd6b5fb442597be69f53b9c0.idx
#      80502 ./files/files/files/files/files/example/.git/objects/pack/pack-967603cfc3620d73cd6b5fb442597be69f53b9c0.pack
#      89358 ./files/files/files/files/files/example/.git/objects/pack
#     102844 ./files/files/files/files/files/example/.git/objects
#         41 ./files/files/files/files/files/example/.git/refs/heads/master
#         41 ./files/files/files/files/files/example/.git/refs/heads
#         32 ./files/files/files/files/files/example/.git/refs/remotes/origin/HEAD
#         41 ./files/files/files/files/files/example/.git/refs/remotes/origin/master
#         73 ./files/files/files/files/files/example/.git/refs/remotes/origin
#         73 ./files/files/files/files/files/example/.git/refs/remotes
#          0 ./files/files/files/files/files/example/.git/refs/tags
#        114 ./files/files/files/files/files/example/.git/refs
#          0 ./files/files/files/files/files/example/.git/rr-cache
#        345 ./files/files/files/files/files/example/.git/COMMIT_EDITMSG
#         23 ./files/files/files/files/files/example/.git/HEAD
#          0 ./files/files/files/files/files/example/.git/MERGE_RR
#        256 ./files/files/files/files/files/example/.git/config
#         73 ./files/files/files/files/files/example/.git/description
#       1047 ./files/files/files/files/files/example/.git/index
#        396 ./files/files/files/files/files/example/.git/packed-refs
#     121999 ./files/files/files/files/files/example/.git
#      36309 ./files/files/files/files/files/example/__pycache__/delta.cpython-34.pyc
#      36309 ./files/files/files/files/files/example/__pycache__
#          7 ./files/files/files/files/files/example/docs/.gitignore
#       6766 ./files/files/files/files/files/example/docs/Makefile
#      10589 ./files/files/files/files/files/example/docs/conf.py
#        106 ./files/files/files/files/files/example/docs/delta.rst
#        479 ./files/files/files/files/files/example/docs/index.rst
#       6703 ./files/files/files/files/files/example/docs/make.bat
#         56 ./files/files/files/files/files/example/docs/modules.rst
#      24706 ./files/files/files/files/files/example/docs
#         55 ./files/files/files/files/files/example/.gitignore
#     374965 ./files/files/files/files/files/example/corpus_words.csv
#      39642 ./files/files/files/files/files/example/delta.py
#        691 ./files/files/files/files/files/example/licence.txt
#       2152 ./files/files/files/files/files/example/pydelta.ini
#       2320 ./files/files/files/files/files/example/readme.txt
#         74 ./files/files/files/files/files/example/requirements.txt
#     602913 ./files/files/files/files/files/example
#          0 ./files/files/files/files/files/files/example/.git/branches
#        452 ./files/files/files/files/files/files/example/.git/hooks/applypatch-msg.sample
#        896 ./files/files/files/files/files/files/example/.git/hooks/commit-msg.sample
#        189 ./files/files/files/files/files/files/example/.git/hooks/post-update.sample
#        398 ./files/files/files/files/files/files/example/.git/hooks/pre-applypatch.sample
#       1642 ./files/files/files/files/files/files/example/.git/hooks/pre-commit.sample
#       1352 ./files/files/files/files/files/files/example/.git/hooks/pre-push.sample
#       4898 ./files/files/files/files/files/files/example/.git/hooks/pre-rebase.sample
#       1239 ./files/files/files/files/files/files/example/.git/hooks/prepare-commit-msg.sample
#       3611 ./files/files/files/files/files/files/example/.git/hooks/update.sample
#      14677 ./files/files/files/files/files/files/example/.git/hooks
#        240 ./files/files/files/files/files/files/example/.git/info/exclude
#        240 ./files/files/files/files/files/files/example/.git/info
#        394 ./files/files/files/files/files/files/example/.git/logs/refs/heads/master
#        394 ./files/files/files/files/files/files/example/.git/logs/refs/heads
#        190 ./files/files/files/files/files/files/example/.git/logs/refs/remotes/origin/HEAD
#        161 ./files/files/files/files/files/files/example/.git/logs/refs/remotes/origin/master
#        351 ./files/files/files/files/files/files/example/.git/logs/refs/remotes/origin
#        351 ./files/files/files/files/files/files/example/.git/logs/refs/remotes
#        745 ./files/files/files/files/files/files/example/.git/logs/refs
#       1239 ./files/files/files/files/files/files/example/.git/logs/HEAD
#       1984 ./files/files/files/files/files/files/example/.git/logs
#        203 ./files/files/files/files/files/files/example/.git/objects/4b/48dc44712e6c87482bf04b465fecd5ab3409f7
#        203 ./files/files/files/files/files/files/example/.git/objects/4b
#      13061 ./files/files/files/files/files/files/example/.git/objects/c5/9897ae9cc1276e830938b14832cceecd31b819
#      13061 ./files/files/files/files/files/files/example/.git/objects/c5
#        222 ./files/files/files/files/files/files/example/.git/objects/db/10c710e062acf0f3bd88e615a8a0bf8740bb73
#        222 ./files/files/files/files/files/files/example/.git/objects/db
#          0 ./files/files/files/files/files/files/example/.git/objects/info
#       8856 ./files/files/files/files/files/files/example/.git/objects/pack/pack-967603cfc3620d73cd6b5fb442597be69f53b9c0.idx
#      80502 ./files/files/files/files/files/files/example/.git/objects/pack/pack-967603cfc3620d73cd6b5fb442597be69f53b9c0.pack
#      89358 ./files/files/files/files/files/files/example/.git/objects/pack
#     102844 ./files/files/files/files/files/files/example/.git/objects
#         41 ./files/files/files/files/files/files/example/.git/refs/heads/master
#         41 ./files/files/files/files/files/files/example/.git/refs/heads
#         32 ./files/files/files/files/files/files/example/.git/refs/remotes/origin/HEAD
#         41 ./files/files/files/files/files/files/example/.git/refs/remotes/origin/master
#         73 ./files/files/files/files/files/files/example/.git/refs/remotes/origin
#         73 ./files/files/files/files/files/files/example/.git/refs/remotes
#          0 ./files/files/files/files/files/files/example/.git/refs/tags
#        114 ./files/files/files/files/files/files/example/.git/refs
#          0 ./files/files/files/files/files/files/example/.git/rr-cache
#        345 ./files/files/files/files/files/files/example/.git/COMMIT_EDITMSG
#         23 ./files/files/files/files/files/files/example/.git/HEAD
#          0 ./files/files/files/files/files/files/example/.git/MERGE_RR
#        256 ./files/files/files/files/files/files/example/.git/config
#         73 ./files/files/files/files/files/files/example/.git/description
#       1047 ./files/files/files/files/files/files/example/.git/index
#        396 ./files/files/files/files/files/files/example/.git/packed-refs
#     121999 ./files/files/files/files/files/files/example/.git
#      36309 ./files/files/files/files/files/files/example/__pycache__/delta.cpython-34.pyc
#      36309 ./files/files/files/files/files/files/example/__pycache__
#          7 ./files/files/files/files/files/files/example/docs/.gitignore
#       6766 ./files/files/files/files/files/files/example/docs/Makefile
#      10589 ./files/files/files/files/files/files/example/docs/conf.py
#        106 ./files/files/files/files/files/files/example/docs/delta.rst
#        479 ./files/files/files/files/files/files/example/docs/index.rst
#       6703 ./files/files/files/files/files/files/example/docs/make.bat
#         56 ./files/files/files/files/files/files/example/docs/modules.rst
#      24706 ./files/files/files/files/files/files/example/docs
#         55 ./files/files/files/files/files/files/example/.gitignore
#     374965 ./files/files/files/files/files/files/example/corpus_words.csv
#      39642 ./files/files/files/files/files/files/example/delta.py
#        691 ./files/files/files/files/files/files/example/licence.txt
#       2152 ./files/files/files/files/files/files/example/pydelta.ini
#       2320 ./files/files/files/files/files/files/example/readme.txt
#         74 ./files/files/files/files/files/files/example/requirements.txt
#     602913 ./files/files/files/files/files/files/example
#          0 ./files/files/files/files/files/files/files/example/.git/branches
#        452 ./files/files/files/files/files/files/files/example/.git/hooks/applypatch-msg.sample
#        896 ./files/files/files/files/files/files/files/example/.git/hooks/commit-msg.sample
#        189 ./files/files/files/files/files/files/files/example/.git/hooks/post-update.sample
#        398 ./files/files/files/files/files/files/files/example/.git/hooks/pre-applypatch.sample
#       1642 ./files/files/files/files/files/files/files/example/.git/hooks/pre-commit.sample
#       1352 ./files/files/files/files/files/files/files/example/.git/hooks/pre-push.sample
#       4898 ./files/files/files/files/files/files/files/example/.git/hooks/pre-rebase.sample
#       1239 ./files/files/files/files/files/files/files/example/.git/hooks/prepare-commit-msg.sample
#       3611 ./files/files/files/files/files/files/files/example/.git/hooks/update.sample
#      14677 ./files/files/files/files/files/files/files/example/.git/hooks
#        240 ./files/files/files/files/files/files/files/example/.git/info/exclude
#        240 ./files/files/files/files/files/files/files/example/.git/info
#        394 ./files/files/files/files/files/files/files/example/.git/logs/refs/heads/master
#        394 ./files/files/files/files/files/files/files/example/.git/logs/refs/heads
#        190 ./files/files/files/files/files/files/files/example/.git/logs/refs/remotes/origin/HEAD
#        161 ./files/files/files/files/files/files/files/example/.git/logs/refs/remotes/origin/master
#        351 ./files/files/files/files/files/files/files/example/.git/logs/refs/remotes/origin
#        351 ./files/files/files/files/files/files/files/example/.git/logs/refs/remotes
#        745 ./files/files/files/files/files/files/files/example/.git/logs/refs
#       1239 ./files/files/files/files/files/files/files/example/.git/logs/HEAD
#       1984 ./files/files/files/files/files/files/files/example/.git/logs
#        203 ./files/files/files/files/files/files/files/example/.git/objects/4b/48dc44712e6c87482bf04b465fecd5ab3409f7
#        203 ./files/files/files/files/files/files/files/example/.git/objects/4b
#      13061 ./files/files/files/files/files/files/files/example/.git/objects/c5/9897ae9cc1276e830938b14832cceecd31b819
#      13061 ./files/files/files/files/files/files/files/example/.git/objects/c5
#        222 ./files/files/files/files/files/files/files/example/.git/objects/db/10c710e062acf0f3bd88e615a8a0bf8740bb73
#        222 ./files/files/files/files/files/files/files/example/.git/objects/db
#          0 ./files/files/files/files/files/files/files/example/.git/objects/info
#       8856 ./files/files/files/files/files/files/files/example/.git/objects/pack/pack-967603cfc3620d73cd6b5fb442597be69f53b9c0.idx
#      80502 ./files/files/files/files/files/files/files/example/.git/objects/pack/pack-967603cfc3620d73cd6b5fb442597be69f53b9c0.pack
#      89358 ./files/files/files/files/files/files/files/example/.git/objects/pack
#     102844 ./files/files/files/files/files/files/files/example/.git/objects
#         41 ./files/files/files/files/files/files/files/example/.git/refs/heads/master
#         41 ./files/files/files/files/files/files/files/example/.git/refs/heads
#         32 ./files/files/files/files/files/files/files/example/.git/refs/remotes/origin/HEAD
#         41 ./files/files/files/files/files/files/files/example/.git/refs/remotes/origin/master
#         73 ./files/files/files/files/files/files/files/example/.git/refs/remotes/origin
#         73 ./files/files/files/files/files/files/files/example/.git/refs/remotes
#          0 ./files/files/files/files/files/files/files/example/.git/refs/tags
#        114 ./files/files/files/files/files/files/files/example/.git/refs
#          0 ./files/files/files/files/files/files/files/example/.git/rr-cache
#        345 ./files/files/files/files/files/files/files/example/.git/COMMIT_EDITMSG
#         23 ./files/files/files/files/files/files/files/example/.git/HEAD
#          0 ./files/files/files/files/files/files/files/example/.git/MERGE_RR
#        256 ./files/files/files/files/files/files/files/example/.git/config
#         73 ./files/files/files/files/files/files/files/example/.git/description
#       1047 ./files/files/files/files/files/files/files/example/.git/index
#        396 ./files/files/files/files/files/files/files/example/.git/packed-refs
#     121999 ./files/files/files/files/files/files/files/example/.git
#      36309 ./files/files/files/files/files/files/files/example/__pycache__/delta.cpython-34.pyc
#      36309 ./files/files/files/files/files/files/files/example/__pycache__
#          7 ./files/files/files/files/files/files/files/example/docs/.gitignore
#       6766 ./files/files/files/files/files/files/files/example/docs/Makefile
#      10589 ./files/files/files/files/files/files/files/example/docs/conf.py
#        106 ./files/files/files/files/files/files/files/example/docs/delta.rst
#        479 ./files/files/files/files/files/files/files/example/docs/index.rst
#       6703 ./files/files/files/files/files/files/files/example/docs/make.bat
#         56 ./files/files/files/files/files/files/files/example/docs/modules.rst
#      24706 ./files/files/files/files/files/files/files/example/docs
#         55 ./files/files/files/files/files/files/files/example/.gitignore
#     374965 ./files/files/files/files/files/files/files/example/corpus_words.csv
#      39642 ./files/files/files/files/files/files/files/example/delta.py
#        691 ./files/files/files/files/files/files/files/example/licence.txt
#       2152 ./files/files/files/files/files/files/files/example/pydelta.ini
#       2320 ./files/files/files/files/files/files/files/example/readme.txt
#         74 ./files/files/files/files/files/files/files/example/requirements.txt
#     602913 ./files/files/files/files/files/files/files/example
#          0 ./files/files/files/files/files/files/files/files/example/.git/branches
#        452 ./files/files/files/files/files/files/files/files/example/.git/hooks/applypatch-msg.sample
#        896 ./files/files/files/files/files/files/files/files/example/.git/hooks/commit-msg.sample
#        189 ./files/files/files/files/files/files/files/files/example/.git/hooks/post-update.sample
#        398 ./files/files/files/files/files/files/files/files/example/.git/hooks/pre-applypatch.sample
#       1642 ./files/files/files/files/files/files/files/files/example/.git/hooks/pre-commit.sample
#       1352 ./files/files/files/files/files/files/files/files/example/.git/hooks/pre-push.sample
#       4898 ./files/files/files/files/files/files/files/files/example/.git/hooks/pre-rebase.sample
#       1239 ./files/files/files/files/files/files/files/files/example/.git/hooks/prepare-commit-msg.sample
#       3611 ./files/files/files/files/files/files/files/files/example/.git/hooks/update.sample
#      14677 ./files/files/files/files/files/files/files/files/example/.git/hooks
#        240 ./files/files/files/files/files/files/files/files/example/.git/info/exclude
#        240 ./files/files/files/files/files/files/files/files/example/.git/info
#        394 ./files/files/files/files/files/files/files/files/example/.git/logs/refs/heads/master
#        394 ./files/files/files/files/files/files/files/files/example/.git/logs/refs/heads
#        190 ./files/files/files/files/files/files/files/files/example/.git/logs/refs/remotes/origin/HEAD
#        161 ./files/files/files/files/files/files/files/files/example/.git/logs/refs/remotes/origin/master
#        351 ./files/files/files/files/files/files/files/files/example/.git/logs/refs/remotes/origin
#        351 ./files/files/files/files/files/files/files/files/example/.git/logs/refs/remotes
#        745 ./files/files/files/files/files/files/files/files/example/.git/logs/refs
#       1239 ./files/files/files/files/files/files/files/files/example/.git/logs/HEAD
#       1984 ./files/files/files/files/files/files/files/files/example/.git/logs
#        203 ./files/files/files/files/files/files/files/files/example/.git/objects/4b/48dc44712e6c87482bf04b465fecd5ab3409f7
#        203 ./files/files/files/files/files/files/files/files/example/.git/objects/4b
#      13061 ./files/files/files/files/files/files/files/files/example/.git/objects/c5/9897ae9cc1276e830938b14832cceecd31b819
#      13061 ./files/files/files/files/files/files/files/files/example/.git/objects/c5
#        222 ./files/files/files/files/files/files/files/files/example/.git/objects/db/10c710e062acf0f3bd88e615a8a0bf8740bb73
#        222 ./files/files/files/files/files/files/files/files/example/.git/objects/db
#          0 ./files/files/files/files/files/files/files/files/example/.git/objects/info
#       8856 ./files/files/files/files/files/files/files/files/example/.git/objects/pack/pack-967603cfc3620d73cd6b5fb442597be69f53b9c0.idx
#      80502 ./files/files/files/files/files/files/files/files/example/.git/objects/pack/pack-967603cfc3620d73cd6b5fb442597be69f53b9c0.pack
#      89358 ./files/files/files/files/files/files/files/files/example/.git/objects/pack
#     102844 ./files/files/files/files/files/files/files/files/example/.git/objects
#         41 ./files/files/files/files/files/files/files/files/example/.git/refs/heads/master
#         41 ./files/files/files/files/files/files/files/files/example/.git/refs/heads
#         32 ./files/files/files/files/files/files/files/files/example/.git/refs/remotes/origin/HEAD
#         41 ./files/files/files/files/files/files/files/files/example/.git/refs/remotes/origin/master
#         73 ./files/files/files/files/files/files/files/files/example/.git/refs/remotes/origin
#         73 ./files/files/files/files/files/files/files/files/example/.git/refs/remotes
#          0 ./files/files/files/files/files/files/files/files/example/.git/refs/tags
#        114 ./files/files/files/files/files/files/files/files/example/.git/refs
#          0 ./files/files/files/files/files/files/files/files/example/.git/rr-cache
#        345 ./files/files/files/files/files/files/files/files/example/.git/COMMIT_EDITMSG
#         23 ./files/files/files/files/files/files/files/files/example/.git/HEAD
#          0 ./files/files/files/files/files/files/files/files/example/.git/MERGE_RR
#        256 ./files/files/files/files/files/files/files/files/example/.git/config
#         73 ./files/files/files/files/files/files/files/files/example/.git/description
#       1047 ./files/files/files/files/files/files/files/files/example/.git/index
#        396 ./files/files/files/files/files/files/files/files/example/.git/packed-refs
#     121999 ./files/files/files/files/files/files/files/files/example/.git
#      36309 ./files/files/files/files/files/files/files/files/example/__pycache__/delta.cpython-34.pyc
#      36309 ./files/files/files/files/files/files/files/files/example/__pycache__
#          7 ./files/files/files/files/files/files/files/files/example/docs/.gitignore
#       6766 ./files/files/files/files/files/files/files/files/example/docs/Makefile
#      10589 ./files/files/files/files/files/files/files/files/example/docs/conf.py
#        106 ./files/files/files/files/files/files/files/files/example/docs/delta.rst
#        479 ./files/files/files/files/files/files/files/files/example/docs/index.rst
#       6703 ./files/files/files/files/files/files/files/files/example/docs/make.bat
#         56 ./files/files/files/files/files/files/files/files/example/docs/modules.rst
#      24706 ./files/files/files/files/files/files/files/files/example/docs
#         55 ./files/files/files/files/files/files/files/files/example/.gitignore
#     374965 ./files/files/files/files/files/files/files/files/example/corpus_words.csv
#      39642 ./files/files/files/files/files/files/files/files/example/delta.py
#        691 ./files/files/files/files/files/files/files/files/example/licence.txt
#       2152 ./files/files/files/files/files/files/files/files/example/pydelta.ini
#       2320 ./files/files/files/files/files/files/files/files/example/readme.txt
#         74 ./files/files/files/files/files/files/files/files/example/requirements.txt
#     602913 ./files/files/files/files/files/files/files/files/example
#          0 ./files/files/files/files/files/files/files/files/files/example/.git/branches
#        452 ./files/files/files/files/files/files/files/files/files/example/.git/hooks/applypatch-msg.sample
#        896 ./files/files/files/files/files/files/files/files/files/example/.git/hooks/commit-msg.sample
#        189 ./files/files/files/files/files/files/files/files/files/example/.git/hooks/post-update.sample
#        398 ./files/files/files/files/files/files/files/files/files/example/.git/hooks/pre-applypatch.sample
#       1642 ./files/files/files/files/files/files/files/files/files/example/.git/hooks/pre-commit.sample
#       1352 ./files/files/files/files/files/files/files/files/files/example/.git/hooks/pre-push.sample
#       4898 ./files/files/files/files/files/files/files/files/files/example/.git/hooks/pre-rebase.sample
#       1239 ./files/files/files/files/files/files/files/files/files/example/.git/hooks/prepare-commit-msg.sample
#       3611 ./files/files/files/files/files/files/files/files/files/example/.git/hooks/update.sample
#      14677 ./files/files/files/files/files/files/files/files/files/example/.git/hooks
#        240 ./files/files/files/files/files/files/files/files/files/example/.git/info/exclude
#        240 ./files/files/files/files/files/files/files/files/files/example/.git/info
#        394 ./files/files/files/files/files/files/files/files/files/example/.git/logs/refs/heads/master
#        394 ./files/files/files/files/files/files/files/files/files/example/.git/logs/refs/heads
#        190 ./files/files/files/files/files/files/files/files/files/example/.git/logs/refs/remotes/origin/HEAD
#        161 ./files/files/files/files/files/files/files/files/files/example/.git/logs/refs/remotes/origin/master
#        351 ./files/files/files/files/files/files/files/files/files/example/.git/logs/refs/remotes/origin
#        351 ./files/files/files/files/files/files/files/files/files/example/.git/logs/refs/remotes
#        745 ./files/files/files/files/files/files/files/files/files/example/.git/logs/refs
#       1239 ./files/files/files/files/files/files/files/files/files/example/.git/logs/HEAD
#       1984 ./files/files/files/files/files/files/files/files/files/example/.git/logs
#        203 ./files/files/files/files/files/files/files/files/files/example/.git/objects/4b/48dc44712e6c87482bf04b465fecd5ab3409f7
#        203 ./files/files/files/files/files/files/files/files/files/example/.git/objects/4b
#      13061 ./files/files/files/files/files/files/files/files/files/example/.git/objects/c5/9897ae9cc1276e830938b14832cceecd31b819
#      13061 ./files/files/files/files/files/files/files/files/files/example/.git/objects/c5
#        222 ./files/files/files/files/files/files/files/files/files/example/.git/objects/db/10c710e062acf0f3bd88e615a8a0bf8740bb73
#        222 ./files/files/files/files/files/files/files/files/files/example/.git/objects/db
#          0 ./files/files/files/files/files/files/files/files/files/example/.git/objects/info
#       8856 ./files/files/files/files/files/files/files/files/files/example/.git/objects/pack/pack-967603cfc3620d73cd6b5fb442597be69f53b9c0.idx
#      80502 ./files/files/files/files/files/files/files/files/files/example/.git/objects/pack/pack-967603cfc3620d73cd6b5fb442597be69f53b9c0.pack
#      89358 ./files/files/files/files/files/files/files/files/files/example/.git/objects/pack
#     102844 ./files/files/files/files/files/files/files/files/files/example/.git/objects
#         41 ./files/files/files/files/files/files/files/files/files/example/.git/refs/heads/master
#         41 ./files/files/files/files/files/files/files/files/files/example/.git/refs/heads
#         32 ./files/files/files/files/files/files/files/files/files/example/.git/refs/remotes/origin/HEAD
#         41 ./files/files/files/files/files/files/files/files/files/example/.git/refs/remotes/origin/master
#         73 ./files/files/files/files/files/files/files/files/files/example/.git/refs/remotes/origin
#         73 ./files/files/files/files/files/files/files/files/files/example/.git/refs/remotes
#          0 ./files/files/files/files/files/files/files/files/files/example/.git/refs/tags
#        114 ./files/files/files/files/files/files/files/files/files/example/.git/refs
#          0 ./files/files/files/files/files/files/files/files/files/example/.git/rr-cache
#        345 ./files/files/files/files/files/files/files/files/files/example/.git/COMMIT_EDITMSG
#         23 ./files/files/files/files/files/files/files/files/files/example/.git/HEAD
#          0 ./files/files/files/files/files/files/files/files/files/example/.git/MERGE_RR
#        256 ./files/files/files/files/files/files/files/files/files/example/.git/config
#         73 ./files/files/files/files/files/files/files/files/files/example/.git/description
#       1047 ./files/files/files/files/files/files/files/files/files/example/.git/index
#        396 ./files/files/files/files/files/files/files/files/files/example/.git/packed-refs
#     121999 ./files/files/files/files/files/files/files/files/files/example/.git
#      36309 ./files/files/files/files/files/files/files/files/files/example/__pycache__/delta.cpython-34.pyc
#      36309 ./files/files/files/files/files/files/files/files/files/example/__pycache__
#          7 ./files/files/files/files/files/files/files/files/files/example/docs/.gitignore
#       6766 ./files/files/files/files/files/files/files/files/files/example/docs/Makefile
#      10589 ./files/files/files/files/files/files/files/files/files/example/docs/conf.py
#        106 ./files/files/files/files/files/files/files/files/files/example/docs/delta.rst
#        479 ./files/files/files/files/files/files/files/files/files/example/docs/index.rst
#       6703 ./files/files/files/files/files/files/files/files/files/example/docs/make.bat
#         56 ./files/files/files/files/files/files/files/files/files/example/docs/modules.rst
#      24706 ./files/files/files/files/files/files/files/files/files/example/docs
#         55 ./files/files/files/files/files/files/files/files/files/example/.gitignore
#     374965 ./files/files/files/files/files/files/files/files/files/example/corpus_words.csv
#      39642 ./files/files/files/files/files/files/files/files/files/example/delta.py
#        691 ./files/files/files/files/files/files/files/files/files/example/licence.txt
#       2152 ./files/files/files/files/files/files/files/files/files/example/pydelta.ini
#       2320 ./files/files/files/files/files/files/files/files/files/example/readme.txt
#         74 ./files/files/files/files/files/files/files/files/files/example/requirements.txt
#     602913 ./files/files/files/files/files/files/files/files/files/example
#          0 ./files/files/files/files/files/files/files/files/files/files/example/.git/branches
#        452 ./files/files/files/files/files/files/files/files/files/files/example/.git/hooks/applypatch-msg.sample
#        896 ./files/files/files/files/files/files/files/files/files/files/example/.git/hooks/commit-msg.sample
#        189 ./files/files/files/files/files/files/files/files/files/files/example/.git/hooks/post-update.sample
#        398 ./files/files/files/files/files/files/files/files/files/files/example/.git/hooks/pre-applypatch.sample
#       1642 ./files/files/files/files/files/files/files/files/files/files/example/.git/hooks/pre-commit.sample
# ...
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      13         for name in os.listdir(path):   # Verzeichnis listen
#      14             subdir = os.path.join(path, name)   # Pfad zusammenbauen
# ---> 15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
#      17         size = os.path.getsize(path)
#
# <ipython-input-20-8106ba9aed11> in total_size(path)
#      15             size += total_size(subdir)  # Eintragsgröße ermitteln und dazuzählen
#      16     else: # kein Verzeichnis: Datei. Der Fall ist einfach.
# ---> 17         size = os.path.getsize(path)
#      18         # oder size = os.stat(path).st_size
#      19
#
# /usr/lib/python3.4/genericpath.py in getsize(filename)
#      48 def getsize(filename):
#      49     """Return the size of a file, reported by os.stat()."""
# ---> 50     return os.stat(filename).st_size
#      51
#      52
#
# OSError: [Errno 40] Too many levels of symbolic links: './files/files/files/files/files/files/files/files/files/files/files/files/files/files/files/files/files/files/files/files/files/files/files/files/files/files/files/files/files/files/files/files/files/files/files/files/files/files/files/files/example'

# %% [markdown]
# ### Debugging (Spyder)

# %% [markdown]
# ![](images/spyder_debugging.png)

# %% [markdown]
# ## Wiederholung: [Reguläre Ausdrücke](08_re.slides.html)
#
# * Minisprache zur Beschreibung von Klassen von Strings
# * Suchen, Ersetzen, Informationen extrahieren
# * Ein **Pattern** **matcht** auf einen String, bzw. auf Teilstrings
# * Entwickeln z.B. mit [pythex.org](http://pythex.org)

# %%
import re
re.findall("[0-9]+", "Jeden Mittwoch von 10 bis 12 lernen wir Python.")
# Out:
# ['10', '12']

# %% [markdown]
# <h3>Special characters</h3>
# <table>
#     <tbody><tr>
#             <td class="key_td"><code>\</code></td>
#             <td>escape special characters</td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>.</code></td>
#             <td>matches any character</td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>^</code></td>
#             <td>matches beginning of string</td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>$</code></td>
#             <td>matches end of string</td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>[5b-d]</code></td>
#             <td>matches any chars '5', 'b', 'c' or 'd'</td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>[^a-c6]</code></td>
#             <td>matches any char except 'a', 'b', 'c' or '6'</td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>R|S</code></td>
#             <td>matches either regex <code>R</code> or regex <code>S</code></td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>()</code></td>
#             <td>creates a capture group and indicates precedence</td>
#         </tr>
#     </tbody>
# </table>
# <h3>Quantifiers</h3>
# <table>
#     <tbody><tr>
#             <td class="key_td"><code>*</code></td>
#             <td>0 or more (append <code>?</code> for non-greedy)</td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>+</code></td>
#             <td>1 or more (append <code>?</code> for non-greedy)</td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>?</code></td>
#             <td>0 or 1 (append <code>?</code> for non-greedy)</td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>{m}</code></td>
#             <td>exactly <code>m</code> occurrences</td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>{m, n}</code></td>
#             <td>from <code>m</code> to <code>n</code>. <code>m</code> defaults to 0, <code>n</code> to infinity</td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>{m, n}?</code></td>
#             <td>from <code>m</code> to <code>n</code>, as few as possible</td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <h3>Special sequences</h3>
# <table>
#     <tbody><tr>
#             <td class="key_td"><code>\A</code></td>
#             <td>start of string</td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>\b</code></td>
#             <td>matches empty string at word boundary (between <code>\w</code> and <code>\W</code>)</td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>\B</code></td>
#             <td>matches empty string not at word boundary</td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>\d</code></td>
#             <td>digit</td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>\D</code></td>
#             <td>non-digit</td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>\s</code></td>
#             <td>whitespace: <code>[ \t\n\r\f\v]</code></td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>\S</code></td>
#             <td>non-whitespace</td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>\w</code></td>
#             <td>alphanumeric: <code>[0-9a-zA-Z_]</code></td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>\W</code></td>
#             <td>non-alphanumeric</td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>\Z</code></td>
#             <td>end of string</td>
#         </tr>
#         <tr>
#             <td class="key_td">`\1`, `\2`, ...</td>
#             <td>matches a previously defined group</td>
#         </tr>
#     </tbody>
# </table>
# <h3>Für Fortgeschrittene: Spezielle Sequenzen, siehe Doku</h3>
# <table>
#     <tbody><tr>
#             <td class="key_td"><code>(?iLmsux)</code></td>
#             <td>matches empty string, sets re.X flags</td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>(?:...)</code></td>
#             <td>non-capturing version of regular parentheses</td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>(?P<name>...)</name></code></td>
#             <td>matches whatever matched previously named group</td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>(?P=<name>)</name></code></td>
#             <td>digit</td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>(?#...)</code></td>
#             <td>a comment; ignored</td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>(?=...)</code></td>
#             <td>lookahead assertion: matches without consuming</td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>(?!...)</code></td>
#             <td>negative lookahead assertion</td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>(?&lt;=...)</code></td>
#             <td>lookbehind assertion: matches if preceded</td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>(?&lt;!...)</code></td>
#             <td>negative lookbehind assertion</td>
#         </tr>
#         <tr>
#             <td class="key_td"><code>(?(id)yes|no)</code></td>
#             <td>match 'yes' if group 'id' matched, else 'no'</td></tr></tbody>
# </table>

# %% [markdown]
# ### Reguläre Ausdrücke anwenden (2)
#
# ![Übersicht über das re-Modul](images/re-uebersicht.svg)

# %% [markdown]
# ### Aufgabe
#
# Schreiben Sie einen einfachen Tokenizer: Der Tokenizer soll eine Textdatei zeilenweise einlesen und jede Zeile in Tokens (Wörter und Zahlen) zerlegen. Ihr Tokenizer soll als Funktion aufrufbar sein und eine lange Sequenz / Liste mit allen Tokens aus der Datei zurückgeben. Alle Tokens sollen in Kleinbuchstaben normalisiert werden.

# %%
import re

def tokenize(filename):
    tokens = []
    
    with open(filename, "rt", encoding="utf-8") as file:
        for line in file:
            for token in re.findall("\w+", line):
                tokens.append(token.lower())
    
    return tokens

print(tokenize("roman.txt"))
# Out:
# ['kurzer', 'roman', 'dies', 'ist', 'ein', 'langer', 'roman', 'er', 'beginnt', 'mit', 'dem', 'auftritt', 'des', 'heldens', 'da', 'es', 'keine', 'helden', 'gibt', 'unterbricht', 'hier', 'schon', 'der', 'leser']

# %% [markdown]
# ### Übungsufgabe
#
# Schreiben Sie ein Programm, das mithilfe von regulären Ausdrücken aus einer XML-Datei sämtliches Markup entfernt und lediglich den Textinhalt in eine neue Datei schreibt. Verwenden Sie eine TEI-Datei von [textgridrep.de](http://textgridrep.de) als Testfall.

# %% [markdown]
# ## Einführung in das Programmieren mit Python
# # Objektorientiertes Programmieren in Python

# %% [markdown]
# ### Objektorientierte Programmierung – Idee und Konzept
#
# * zusammengehörige Daten werden in einen gemeinsamen Container zusammengefasst
# * Operationen auf diesen Daten kommen ebenfalls in diesen Container
# * Ergebnis: **Objekt**, das seine internen Daten kapselt und Operationen anbietet

# %%
"Hallo".lower()
# Out:
# 'hallo'

# %% [markdown]
# ### Begriffe
#
# * **Objekt** oder **Instanz**  (z.B. `"Hallo"`)
#    * in Python ist _alles_ ein Objekt
# * **Attribute** oder **Eigenschaften** (oder **Felder**)
#    * Zugriff per `objekt.feld`
#    * les- und ggf. schreibbar
# * **Methoden**
#    * Funktionen, die teil eines Objekts sind und mit dem Objekt arbeiten

# %%
f = open("roman.txt")
print(f.encoding)
print(f.read())
# Out:
# UTF-8
# Kurzer Roman.
# Dies ist ein langer Roman. Er beginnt mit dem Auftritt des Heldens.
# Da es keine Helden gibt, unterbricht hier schon der Leser …

# %% [markdown]
# ### Klassen
#
# * Der _Datentyp_ eines Objekts ist seine **Klasse**
# * Klasse = »Bauplan« für die Objekte, definiert die Methoden (und Eigenschaften)

# %%
print(type("Hallo"))
# Out:
# <class 'str'>

# %%
class Person:
    """
    Eine Person.
    """
    
    def __init__(self, name, email):
        """
        Erzeugt eine neue Person.
        """
        self.name = name
        self.email = email
        
    def formattedOutput(self):
        """
        Liefert einen String zurück, der diese Person beschreibt.
        """
        return self.name + ' <' + self.email + '>'
    
    def describe(self):
        """
        Beschreibt diese Person.
        """
        print(self.formattedOutput())
        
max = Person("Max Müller", "max.mueller@example.com")
max.describe()
# Out:
# Max Müller <max.mueller@example.com>

# %%
print(max.name)
# Out:
# Max Müller

# %%
print(type(max))
# Out:
# <class '__main__.Person'>

# %% [markdown]
# ### Klassen im Detail
# Eine _Klassendefinition_ erzeugt eine Klasse und weist sie einem Klassennamen zu:
# ```
# class Person:
# ```
# Dabei entsteht ein Block (durch Einrückung). In diesem Block stehen Eigenschaften (der Klasse! z.B. Docstring) und Methoden.
#
# * Per Konvention beginnen Klassennamen mit einem Großbuchstaben
# * Eine Klasse kann als Funktion aufgerufen werden:
# ```
# max = Person("Max Müller", "max.mueller@example.com")
# ```
# * Dadurch wird ein _Objekt_ dieser Klasse erzeugt, so wie z.B. `list(1, 2, 3)` ein Objekt der Klasse `list` erzeugt
# * `Person(...)` = __Konstruktoraufruf__
# * die Argumente werden an die spezielle Methode `__init__` übergeben

# %% [markdown]
# ### Methoden
#
# * Eine Funktion, die in einer Klassendefinition erzeugt wird, heißt _Methode_.
# * Methoden bekommen ein erstes Argument, das immer `self` heißen sollte
# * darin wird der Methode das Objekt (= die Instanz) übergeben

# %%
class Beispiel:
    def whatami(self):
        print(type(self))
bsp = Beispiel()
bsp.whatami()
# Out:
# <class '__main__.Beispiel'>

# %% [markdown]
# ### Initialisierung
# * Es gibt Methoden mit Spezialbedeutung: Namenskonvention `__irgendwas__`
# * Beispiel Initialisierung: `__init__`
# * Wenn `__init__` definiert es, wird es unmittelbar nach der Instantiierung (= Objekterzeugung) mit den Argumenten des Konstruktoraufrufs aufgerufen.
#
# ```
# max = Person("Max", "max@example.com")
# ```
# 1. Objekt der Klasse `Person` wird erzeugt
# 2. (implizit) Aufruf der Methode `__init__` der Objektklasse mit den Argumenten `self` (das Objekt), `"Max"` und `"max@example.com"`
# 3. das erzeugte und initialisierte Objekt wird der Variablen `max` zugewiesen

# %% [markdown]
# ### Attribute
#
# * __Attribute__ sind Eigenschaften eines Objekts
# * Wie Variablen, aber an eine Objektinstanz gekoppelt (in jedem Objekt anders)
# * Zugriff mit `objekt.attribut`, z.B. `max.name`
# * Üblicherweise Initialisierung in der `__init__`-Methode
#
# ```
#     def __init__(self, name, email):
#         self.name = name
#         self.email = email
# ```

# %% [markdown]
# ### Unsere Personklasse (wdh)

# %%
class Person:
    """
    Eine Person.
    """
    
    def __init__(self, name, email):
        """
        Erzeugt eine neue Person.
        """
        self.name = name
        self.email = email
        
    def formattedOutput(self):
        """
        Liefert einen String zurück, der diese Person beschreibt.
        """
        return self.name + ' <' + self.email + '>'
    
    def describe(self):
        """
        Beschreibt diese Person.
        """
        print(self.formattedOutput())
        
max = Person("Max Müller", "max.mueller@example.com")
max.describe()
# Out:
# Max Müller <max.mueller@example.com>

# %%
class Person:
    def __init__(self, name, email):
        self.name = name
        self.email = email        
    def formattedOutput(self):
        return self.name + ' <' + self.email + '>'
    def describe(self):
        print(self.formattedOutput())
        
max = Person("Max Müller", "max.mueller@example.com")
max.describe()
# Out:
# Max Müller <max.mueller@example.com>

# %% [markdown]
# <h3 style="color:green">Aufgaben</h3>
# 1. Definieren Sie eine Klasse mit dem Namen `Text`, der beim Aufruf ein String übergeben wird, z.B.:<br/>
# `t = Text("Dies ist ein kleiner Text. Nicht der Rede wert. Aber immerhin.")`
# 2. Definieren Sie eine Methode der Klasse, die die Länge des Textes zurückgibt.
# 3. Definieren Sie eine weitere Methode, die die Wörter in Form einer Liste zurückgibt.

# %%
class Text:
    def __init__(self, text):
        self.text = text
    def length(self):
        return len(self.text)
    def words(self):
        return self.text.split()
t = Text("Dies ist ein kleiner Text. Nicht der Rede wert. Aber immerhin.")
print("Länge:", t.length())
print("Wörter:", t.words())
# Out:
# Länge: 62
# Wörter: ['Dies', 'ist', 'ein', 'kleiner', 'Text.', 'Nicht', 'der', 'Rede', 'wert.', 'Aber', 'immerhin.']

# %% [markdown]
# <h3 style='color: green'>Übungsaufgabe (für zuhause)</h3>
#
# 1. Definieren Sie eine Klasse `Obst`. Instanzen dieser Klasse sollen für jede Obstsorte den Namen speichern können sowie in welchen Monaten das Obst in unseren Breiten geerntet werden kann.
# 2. Fügen Sie der Klasse eine Methode `verfuegbar(monat)` hinzu, die als Argument ein Monatskürzel nimmt und zurückgibt, ob die Obstsorte in diesem Monat regional verfügbar ist.
# 3. Erzeugen Sie anhand der folgenden Tabelle ([Quelle: regional-saisonal](http://www.regional-saisonal.de/saisonkalender-obst)) Obst-Instanzen und fragen Sie sie beispielhaft, ob die Sorten im Juni und im August verfügbar sind.
# <table border="1">
# 	<tr>
# 		<th class="td_zutat" width="38%">Zutat (Obst)</th>
# 		<th width="6%"><abbr title="Januar">Jan</abbr></th>
# 		<th width="6%"><abbr title="Februar">Feb</abbr></th>
# 		<th width="6%"><abbr title="März">Mär</abbr></th>
# 		<th width="6%"><abbr title="April">Apr</abbr></th>
# 		<th width="6%"><abbr title="Mai">Mai</abbr></th>
# 		<th width="6%"><abbr title="Juni">Jun</abbr></th>
# 		<th width="6%"><abbr title="Juli">Jul</abbr></th>
# 		<th width="6%"><abbr title="August">Aug</abbr></th>
# 		<th width="6%"><abbr title="September">Sep</abbr></th>
# 		<th width="6%"><abbr title="Oktober">Okt</abbr></th>
# 		<th width="6%"><abbr title="November">Nov</abbr></th>
# 		<th width="6%"><abbr title="Dezember">Dez</abbr></th>
# 	</tr>
# 	<tr>
# 		<td class="td_zutat">Aprikosen</td>
# 		<td>nein</td>
# 		<td>nein</td>
# 		<td>nein</td>
# 		<td>nein</td>
# 		<td>nein</td>
# 		<td>nein</td>
# 		<td>ja</td>
# 		<td>ja</td>
# 		<td>nein</td>
# 		<td>nein</td>
# 		<td>nein</td>
# 		<td>nein</td>
# 	</tr>
# 	<tr>
# 		<td class="td_zutat"><a href="http://www.regional-saisonal.de/rezept-zutaten/brombeeren" title="zu den Rezepten mit Brombeeren">Brombeeren</a></td>
# 		<td>nein</td>
# 		<td>nein</td>
# 		<td>nein</td>
# 		<td>nein</td>
# 		<td>nein</td>
# 		<td>nein</td>
# 		<td>ja</td>
# 		<td>ja</td>
# 		<td>ja</td>
# 		<td>nein</td>
# 		<td>nein</td>
# 		<td>nein</td>
# 	</tr>
# 	<tr>
# 		<td class="td_zutat"><a href="http://www.regional-saisonal.de/rezept-zutaten/erdbeeren" title="zu den Rezepten mit Erdbeeren">Erdbeeren</a></td>
# 		<td>nein</td>
# 		<td>nein</td>
# 		<td>nein</td>
# 		<td>nein</td>
# 		<td>ja</td>
# 		<td>ja</td>
# 		<td>ja</td>
# 		<td>nein</td>
# 		<td>nein</td>
# 		<td>nein</td>
# 		<td>nein</td>
# 		<td>nein</td>
# 	</tr>
# </table>

# %%
class Obst:
    
    def __init__(self, name, erntemonate):
        """
        Erzeugt eine neue Obstsorte `name`. `erntemonate` ist eine Liste der Monate à la ['Jan', 'Feb'], 
        die die Erntezeit repräsentiert.
        """
        self.name = name
        self.erntemonate = erntemonate
        
    def verfuegbar(self, monat):
        """Ist das Obst in Monat `monat` (z.B. 'Jan') verfügbar?"""
        return monat in self.erntemonate

aprikosen = Obst("Aprikosen", ["Jul", "Aug"])
brombeeren = Obst("Brombeeren", ["Jul","Aug", "Sep"])
erdbeeren = Obst("Erdbeeren", ["Mai","Jun", "Jul"])

print(aprikosen.verfuegbar("Jun"))
print(aprikosen.verfuegbar("Aug"))
print(erdbeeren.verfuegbar("Jun"))
print(erdbeeren.verfuegbar("Aug"))
# Out:
# False
# True
# True
# False

# %% [markdown]
# ![Vererbung](images/inheritance.png)

# %% [markdown]
# ### Vererbung

# %%
# zur Erinnerung nochmal die Klasse 'Person':
class Person:
    """
    Eine Person.
    """
    
    def __init__(self, name, email):
        """
        Erzeugt eine neue Person.
        """
        self.name = name
        self.email = email
        
    def formattedOutput(self):
        """
        Liefert einen String zurück, der diese Person beschreibt.
        """
        return self.name + ' <' + self.email + '>'
    
    def describe(self):
        """
        Beschreibt diese Person.
        """
        print(self.formattedOutput())
        
max = Person("Max Müller", "max.mueller@example.com")
max.describe()
# Out:
# Max Müller <max.mueller@example.com>

# %% [markdown]
# ### Vererbung
#
# Eine Klasse kann eine _Superklasse_ (_Oberklasse_) haben, deren Eigenschaften sie erbt.

# %%
class Student(Person):    # in Klammern: Superklasse
    
    def __init__(self, name, email, matrikel):
        super().__init__(name, email)  # super() -> Oberklasse
        self.matrikel = matrikel
        
    def formattedOutput(self):
        return self.name + ' <' + self.email + '> (' + str(self.matrikel) + ')'

# %%
moritz = Student("Moritz Maier", "moritz.maier@example.com", 4711)
moritz.describe()
# Out:
# Moritz Maier <moritz.maier@example.com> (4711)

# %%
for p in max, moritz:
    print(p.name, isinstance(p, Person), isinstance(p, Student))
# Out:
# Max Müller True False
# Moritz Maier True True

# %% [markdown]
# ### Vererbung im Detail
#
# Wird eine Klasse definiert, so kann sie mit einer Oberklasse verknüpft werden, deren Eigenschaften sie _erbt_:
#
# ```
# class Student(Person):
# ```
# definiert die Klasse Student, deren Oberklasse Person ist.
#
# * Objekte des Typs `Student` sind _auch_ vom Typ `Person`
# * Objekte vom Typ `Person` sind aber nicht notwendigerweise vom Typ `Student`
# * Alle `Student`en haben die Eigenschaften von `Person`en, die `Student`-Klasse kann Attribute und Methoden jedoch überschreiben

# %% [markdown]
# ### Methoden überschreiben
# * Wird in der Subklasse eine Methode definiert, so wird diese statt die der Oberklasse verwendet
# * in einer Methode kann mit `super()` auf die Oberklasse zugegriffen werden

# %%
class Student(Person):    # in Klammern: Superklasse
    
    def __init__(self, name, email, matrikel):
        super().__init__(name, email)  # super() -> Oberklasse
        self.matrikel = matrikel

# %% [markdown]
# hier wird `__init__` von Person überschrieben und aus der überschreibenden Methode  mithilfe von `super()` aufgerufen

# %% [markdown]
# ### Polymorphie
#
# * Ein Objekt einer Subklasse kann wie das der Superklasse verwendet werden, es werden jedoch ggf. die Methoden der Subklasse verwendet.
# * Beispiel: `Student.formattedOutput` wird aus `Person.describe` aufgerufen ...

# %%
class Student(Person):    # in Klammern: Superklasse
    
    def __init__(self, name, email, matrikel):
        super().__init__(name, email)  # super() -> Oberklasse
        self.matrikel = matrikel
        
    def formattedOutput(self):
        return self.name + ' <' + self.email + '> (' + str(self.matrikel) + ')'

# %%
moritz = Student("Moritz Maier", "moritz.maier@example.com", 4711)
moritz.describe()
# Out:
# Moritz Maier <moritz.maier@example.com> (4711)

# %% [markdown]
# <h3 style='color:green'>Übungsaufgabe</h3>
#
# 1. Manche Obstsorten sind lagerfähig. Erzeugen Sie eine Subklasse `Lagerobst` zu ihrer Obstklasse, die die Monate, in denen eine Obstsorte aus Lagerbeständen verfügbar ist, als zusätzliches Attribut pflegt. Erzeugen Sie Instanzen für Äpfel (Erntezeit August bis November, lagerfähig Dezember bis Mai) und Birnen (Ernte August bis Oktober, lagerfähig bis Dezember)
# 2. Überschreiben Sie die `verfuegbar`-Methode, sodass sie bei Lagerobst auch in den Lagermonaten `True` zurückgibt
# 3. Fügen Sie dem Lagerobst eine Methode hinzu, mit der zwischen frisch und gelagert verfügbarem Obst unterschieden werden kann. Welche Implementierungsmöglichkeiten sind möglich? Diskutieren Sie Vor- und Nachteile.
